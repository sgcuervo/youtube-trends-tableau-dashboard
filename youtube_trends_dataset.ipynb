# %% [markdown]
# Este notebook esta destinado a corroborar que los datos que vamos a utilizar para nuestro dashboard estén limpios.

# %%
import pandas as pd

# %%
youtube_trends = pd.read_csv("datasets/trending_by_time.csv")

# %%
youtube_trends.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12343 entries, 0 to 12342
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   record_id       12343 non-null  int64
#  1   region          12343 non-null  object
#  2   trending_date   12343 non-null  object
#  3   category_title  12343 non-null  object
#  4   videos_count    12343 non-null  int64
# dtypes: int64(2), object(3)
# memory usage: 482.3+ KB

# %%
youtube_trends.head()
# Out:
#    record_id  region               trending_date    category_title  \
# 0          1  France  2017-11-14 00:00:00.000000  Autos & Vehicles
# 1          2  France  2017-11-15 00:00:00.000000  Autos & Vehicles
# 2          3  France  2017-11-16 00:00:00.000000  Autos & Vehicles
# 3          4  France  2017-11-17 00:00:00.000000  Autos & Vehicles
# 4          5  France  2017-11-18 00:00:00.000000  Autos & Vehicles
#
#    videos_count
# 0             8
# 1             2
# 2             6
# 3             8
# 4             4

# %%
youtube_trends.tail()
# Out:
#        record_id         region               trending_date   category_title  \
# 12338      12339  United States  2018-06-10 00:00:00.000000  Travel & Events
# 12339      12340  United States  2018-06-11 00:00:00.000000  Travel & Events
# 12340      12341  United States  2018-06-12 00:00:00.000000  Travel & Events
# 12341      12342  United States  2018-06-13 00:00:00.000000  Travel & Events
# 12342      12343  United States  2018-06-14 00:00:00.000000  Travel & Events
#
#        videos_count
# 12338             2
# 12339             2
# 12340             2
# 12341             2
# 12342             2

# %%
youtube_trends.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# El dataset ya se encuentra limpio y libre de duplicados, limpiar la columna `trending_date` dejando unicamente la fecha

# %%
youtube_trends["trending_date"] = pd.to_datetime(youtube_trends["trending_date"]).dt.date

# %%
youtube_trends.head()
# Out:
#    record_id  region trending_date    category_title  videos_count
# 0          1  France    2017-11-14  Autos & Vehicles             8
# 1          2  France    2017-11-15  Autos & Vehicles             2
# 2          3  France    2017-11-16  Autos & Vehicles             6
# 3          4  France    2017-11-17  Autos & Vehicles             8
# 4          5  France    2017-11-18  Autos & Vehicles             4

# %% [markdown]
# Con esto nuestros datos están listos para trabajar en Tableau

# %%
youtube_trends.to_csv("trending_by_time_clean.csv", index=False)
